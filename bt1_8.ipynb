# %% [markdown]
# - Plotting Multiple Lines in the Same Chart

# %%
import matplotlib.pyplot as plt

# Tạo dữ liệu mẫu
x = [1, 2, 3, 4, 5,6,7,8,9]
y1 = [10, 15, 7, 12, 9, 10, 8, 9 , 6]
y2 = [8, 12, 6, 10, 5, 15, 7, 12, 9]

# Vẽ đường thứ nhất
plt.plot(x, y1, label='Điểm môn A')
# Vẽ đường thứ hai
plt.plot(x, y2, label='Điểm môn B')

# Đặt tiêu đề và nhãn trục
plt.title('Biểu đồ điểm môn học')
plt.xlabel('Tuần')
plt.ylabel('Điểm')

# Hiển thị chú giải
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# - Plotting Bar Charts

# %%
# Tạo dữ liệu mẫu
mon_hoc = ['Javascript', 'Java', 'Python', 'C++', 'C']
diem = [8, 7, 9, 6, 8]

# Vẽ biểu đồ thanh
plt.bar(mon_hoc, diem)

# Đặt tiêu đề và nhãn trục
plt.title('Biểu đồ điểm môn học')
plt.xlabel('Môn học')
plt.ylabel('Điểm')

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# - Display the results collect data in three above forms

# %%
import matplotlib.pyplot as plt
import random

# Generate random student data
student_names = ['ngoc', 'nhi', 'thuy', 'hien', 'thao']
subjects = ['C', 'C++', 'Java', 'Python', 'Swift']
data = []

for student in student_names:
    student_data = {'student_name': student, 'subjects': subjects, 'marks': [random.randint(0, 10) for _ in subjects]}
    data.append(student_data)

# Display multiple lines chart
plt.figure(figsize=(10, 6))
for student_data in data:
    plt.plot(student_data['subjects'], student_data['marks'], label=student_data['student_name'])

plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Multiple Lines Chart')
plt.legend()
plt.show()

# Display bar chart
plt.figure(figsize=(10, 6))
for i, student_data in enumerate(data):
    plt.bar(student_data['subjects'], student_data['marks'], label=student_data['student_name'])

plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Bar Chart')
plt.legend()
plt.show()

# Display table-like data
print("{:<15} {:<15} {:<15} {:<15} {:<15} {:<15}".format("Student", "Math", "Science", "History", "English", "Art"))
for student_data in data:
    print("{:<15} {:<15} {:<15} {:<15} {:<15} {:<15}".format(
        student_data['student_name'],
        student_data['marks'][0],
        student_data['marks'][1],
        student_data['marks'][2],
        student_data['marks'][3],
        student_data['marks'][4]
    ))
# Out:
# Student         Math            Science         History         English         Art
# ngoc            6               9               8               2               1
# nhi             6               10              3               8               6
# thuy            2               8               6               2               7
# hien            3               1               0               10              9
# thao            6               10              3               5               5
